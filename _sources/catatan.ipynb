# %% [markdown]
# # Catatan

# %% [markdown]
# ### Pertemuan Ke-3
#
# 1. ektraksi terkait kata yang unik dari isi berita
# 2. sebelum dilakukan ekstraksi dipreprocessing terlebih dahulu membuang simbol yang ada pada dokumen
# 3. slang word preprocessing harus diubah baku
# 4. bag of word kemunculan kata berapa kali dari semua dokumen
# 5. untuk memeperbaiki bag of word yaitu menggunakan tf idf
# 6. reppresentasikan dokumen tugas ini menggunakan tf idf
# 7.sport 1 finance 0 untuk diubah sesuai dengan label dan diubah dalam bentuk tf idf
# 8. mempersiapkan data untuk analisa
# 9. svd embeding
# 10. reduksi dimensi pada data tfidf menggunakan pca
# 11. 2 data tfidf dan reduksi data
# orange & pca skitlent
